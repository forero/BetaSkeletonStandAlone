# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
full_index_data = loadtxt("../bin/output/om0.2600_w-1.0000.BSKIndex")
full_pos_data = loadtxt("../bin/output/om0.2600_w-1.0000_xyz.txt")

# %%
scatter(full_pos_data[:,0], full_pos_data[:,1])

# %%
for index in full_index_data:
    x_points = array([full_pos_data[index[0],0], full_pos_data[index[1],0]])
    y_points = array([full_pos_data[index[0],1], full_pos_data[index[1],1]])
    plot(x_points, y_points, color="black")
    
scatter(full_pos_data[:,0], full_pos_data[:,1],s=0.2)
